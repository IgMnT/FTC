# %%
import pandas as pd
from haversine import haversine

# %%
df = pd.read_csv('C:\\Users\\IgorMagro\\Downloads\\train.csv')

# %%
numero_entregadores = len(df.loc[:,'Delivery_person_ID'].unique())
print(numero_entregadores)
# Out:
# 1320

# %%
df.loc[:,:]
# Out:
#             ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0      0x4607     INDORES13DEL02                   37                     4.9
# 1      0xb379     BANGRES18DEL02                   34                     4.5
# 2      0x5d6d     BANGRES19DEL01                   23                     4.4
# 3      0x7a6a    COIMBRES13DEL02                   38                     4.7
# 4      0x70a2     CHENRES12DEL01                   32                     4.6
# ...        ...                ...                 ...                     ...
# 45588  0x7c09      JAPRES04DEL01                   30                     4.8
# 45589  0xd641      AGRRES16DEL01                   21                     4.6
# 45590  0x4f8d     CHENRES08DEL03                   30                     4.9
# 45591  0x5eee    COIMBRES11DEL01                   20                     4.7
# 45592  0x5fb2   RANCHIRES09DEL02                   23                     4.9
#
# ...

# %%
dfavg= df.loc[:, ['Delivery_person_ID', 'Delivery_person_Ratings']].groupby('Delivery_person_ID').mean().reset_index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File c:\Python312\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Python312\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# ...

# %%
df['dist'] = df.loc[:,:].apply(lambda x: haversine((x['Restaurant_latitude'], x['Restaurant_longitude']), (x['Delivery_location_latitude'], x['Delivery_location_longitude'])), axis=1)

# %%
df['Restaurant_latitude'] = df['Restaurant_latitude'].astype(float)
df['Restaurant_longitude'] = df['Restaurant_longitude'].astype(float)
df['Delivery_location_latitude'] = df['Delivery_location_latitude'].astype(float)
df['Delivery_location_longitude'] = df['Delivery_location_longitude'].astype(float)

# %%
df['Time_taken(min)'] = df['Time_taken(min)'].str.extract(r'(\d+)').astype(float)

# %%
cols = ['Time_taken(min)', 'City', 'Type_of_order']
mean_median = df.loc[:,cols].groupby(['City', 'Type_of_order']).agg({'Time_taken(min)': ['mean', 'std']})
mean_median
# Out:
#                              Time_taken(min)
#                                         mean       std
# City           Type_of_order
# Metropolitian  Buffet              27.184645  9.210469
#                Drinks              27.222762  9.086536
#                Meal                27.510734  9.251953
#                Snack               27.336991  9.184238
# NaN            Buffet              22.244224  8.313383
#                Drinks              21.569930  7.817682
#                Meal                21.796364  8.153320
#                Snack               22.520833  8.825988
# Semi-Urban     Buffet              49.666667  2.711013
#                Drinks              49.647059  2.435624
#                Meal                50.029412  2.959170
#                Snack               49.648148  2.720692
# Urban          Buffet              23.352073  9.081076
#                Drinks              22.991430  8.933587
#                Meal                22.802414  8.745737
# ...
